# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel('ExternalWood_Tableau récap.xlsx')

# %%
# Find the row index that contains the header 'Catégorie d\'impact'
start_idx = df[df.iloc[:, 0] == "Catégorie d'impact"].index[0]

# Extract the sub-dataframe starting from that row
sub_df = df.iloc[start_idx:]

# Set the new header
sub_df.columns = sub_df.iloc[0]
sub_df = sub_df[1:]  # Drop the header row
sub_df
# Out:
# 5                         Catégorie d'impact         Unité     Moyenne  \
# 6                              Acidification     mol H+ eq    0.002462
# 7                             Climate change     kg CO2 eq   -0.133378
# 8                  Climate change - Biogenic     kg CO2 eq   -1.073184
# 9                    Climate change - Fossil     kg CO2 eq    0.938057
# 10   Climate change - Land use and LU change     kg CO2 eq    0.001749
# 11      Ecotoxicity, freshwater - inorganics          CTUe    1.452632
# 12  Ecotoxicity, freshwater - organics - p.1          CTUe    0.153678
# 13  Ecotoxicity, freshwater - organics - p.2          CTUe    0.090303
# 14          Ecotoxicity, freshwater - part 1          CTUe    1.066921
# 15          Ecotoxicity, freshwater - part 2          CTUe    0.629691
# 16                Eutrophication, freshwater       kg P eq    0.000214
# 17                    Eutrophication, marine       kg N eq    0.000718
# ...
